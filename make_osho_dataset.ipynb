# %% [markdown]
# #### This Notebook performs
#     --- Loading the JSON made in the previous notebook
#     --- Login into Hugging Face
#     --- make a dataset object
#     --- push it to Hugging face
#     --- We name it simply 'osho_discourses'

# %%
#!pip install huggingface_hub
#!pip install datasets

# %%
from datasets import Dataset

# %%
import json
from pprint import pprint
from google.colab import drive

# %%
import os

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
json_loc = './drive/MyDrive/OSHO_TEXT/ds_hf_2.json'
with open(json_loc, 'r', encoding='utf-8') as f:
    final_dict = json.load(f)

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
from datasets import Dataset

# %%
dataset = Dataset.from_dict(final_dict['data'])

# %%
dataset.push_to_hub('DhruvDancingBuddha/osho_discourses')
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/DhruvDancingBudha/osho_discourses/commit/2b1afa8583a812d78ae71f9c9bce94c0eb307c5d', commit_message='Upload dataset', commit_description='', oid='2b1afa8583a812d78ae71f9c9bce94c0eb307c5d', pr_url=None, pr_revision=None, pr_num=None)
